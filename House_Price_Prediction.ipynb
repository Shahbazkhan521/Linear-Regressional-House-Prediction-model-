# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams["figure.figsize"] = [10,5]

# %%
df = pd.read_csv('USA_Housing.csv')

# %%
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
df= df.drop('Address',axis=1)

# %%
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price
# ...

# %% [markdown]
# #name x for input features and y for output variable.

# %%
x = df.drop('Price',axis=1)

# %%
y= df['Price']

# %%
x.shape
# Out:
# (5000, 5)

# %%
y.shape
# Out:
# (5000,)

# %%
x
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population
# 0                             4.09     23086.800503
# ...

# %%
y
# Out:
# 0       1.059034e+06
# 1       1.505891e+06
# 2       1.058988e+06
# 3       1.260617e+06
# 4       6.309435e+05
#             ...
# 4995    1.060194e+06
# 4996    1.482618e+06
# 4997    1.030730e+06
# 4998    1.198657e+06
# 4999    1.298950e+06
# Name: Price, Length: 5000, dtype: float64

# %% [markdown]
# # import Model_selection and divide data into train and test form.

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size= .20 ,random_state=101)

# %%
x_train.shape
# Out:
# (4000, 5)

# %%
y_train.shape
# Out:
# (4000,)

# %%
y_test.shape
# Out:
# (1000,)

# %%
x_test.shape
# Out:
# (1000, 5)

# %% [markdown]
# # Stadardization for input and output features or attributes for machine learnign model.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# fit the scaler to the train set, it will learn the parameters
scaler.fit(x_train)

# transform train and test sets
x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
y_train =np.array(y_train)
y_test =np.array(y_test)

# %%
scaler = StandardScaler()
y_train_scaled = scaler.fit_transform(y_train.reshape(-1,1)).squeeze()
y_test_scaled =  scaler.fit_transform(y_test.reshape(-1,1)).squeeze()

# %%
y_train_scaled
# Out:
# array([ 0.2177987 ,  0.4899976 , -0.51157425, ..., -0.35806046,
#        -1.03333852,  2.50102123])

# %%
scaler.mean_
# Out:
# array([1245981.15764806])

# %%
y_train_scaled
# Out:
# array([ 0.2177987 ,  0.4899976 , -0.51157425, ..., -0.35806046,
#        -1.03333852,  2.50102123])

# %%
x_train_scaled = pd.DataFrame(x_train_scaled, columns=x_train.columns)
x_test_scaled = pd.DataFrame(x_test_scaled, columns=x_test.columns)

# %%
# Reshape y_train and y_test directly
y_train = y_train.reshape(-1, 1)  # Converts to 2D if it's a 1D array
y_test = y_test.reshape(-1, 1)

# Scale the reshaped arrays
y_train_scaled = scaler.fit_transform(y_train)
y_test_scaled = scaler.transform(y_test)

# Wrap the scaled arrays in DataFrames with column names if needed
y_train_scaled = pd.DataFrame(y_train_scaled, columns=['y_train_scaled'])  
y_test_scaled = pd.DataFrame(y_test_scaled, columns=['y_test_scaled'])

# %%
x_test_scaled
# Out:
#      Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0           -0.158144            -0.257493                   0.810350
# 1           -0.589857            -1.060967                   0.442394
# 2            0.487767             0.808251                   1.352855
# 3           -0.615766             0.261515                  -0.393135
# 4            0.421902            -1.202634                   0.334464
# ..                ...                  ...                        ...
# 995          0.861391             0.233351                  -0.076576
# 996         -0.144018            -0.830204                   1.412742
# 997          0.312369            -0.050239                   0.425730
# 998          1.769519            -0.959330                   0.199186
# 999          0.170650            -0.116183                  -0.203935
#
#      Avg. Area Number of Bedrooms  Area Population
# 0                        0.290998         0.061061
# ...

# %%
np.round(y_train_scaled.describe(),1)
# Out:
#        y_train_scaled
# count          4000.0
# mean              0.0
# std               1.0
# min              -3.4
# 25%              -0.7
# 50%               0.0
# 75%               0.7
# max               3.5

# %%
np.round(x_train.describe(),1)
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count            4000.0               4000.0                     4000.0
# mean            68456.6                  6.0                        7.0
# std             10634.5                  1.0                        1.0
# min             17796.6                  2.8                        4.0
# 25%             61281.3                  5.3                        6.3
# 50%             68704.7                  6.0                        7.0
# 75%             75698.1                  6.6                        7.7
# max            107701.7                  9.5                       10.8
#
#        Avg. Area Number of Bedrooms  Area Population
# count                        4000.0           4000.0
# mean                            4.0          36182.6
# std                             1.2           9932.1
# min                             2.0           3285.5
# ...

# %%
np.round(x_train_scaled.describe(),1)
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count            4000.0               4000.0                     4000.0
# mean                0.0                  0.0                        0.0
# std                 1.0                  1.0                        1.0
# min                -4.8                 -3.2                       -3.0
# 25%                -0.7                 -0.7                       -0.7
# 50%                 0.0                  0.0                        0.0
# 75%                 0.7                  0.7                        0.7
# max                 3.7                  3.6                        3.8
#
#        Avg. Area Number of Bedrooms  Area Population
# count                        4000.0           4000.0
# mean                            0.0              0.0
# std                             1.0              1.0
# min                            -1.6             -3.3
# ...

# %% [markdown]
# #import linear regrssion model & train it by using fit function

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_reg = LinearRegression()

# %%
lin_reg.fit(x_train_scaled,y_train_scaled)
# Out:
# LinearRegression()

# %% [markdown]
# # predict values by linear regression model

# %%
y_pred = lin_reg.predict(x_test_scaled)

# %%
print(y_pred.shape)
# Out:
# (1000, 1)

# %%
# Combine actual and predicted values side by side
results = np.column_stack((y_test_scaled, y_pred))

# Printing the results
print("Actual Values  |  Predicted Values")
print("-----------------------------")
for actual, predicted in results:
    print(f"{actual:14.2f} |  {predicted:12.2f}")
# Out:
# Actual Values  |  Predicted Values
# -----------------------------
#           0.07 |          0.08
#          -1.01 |         -1.16
#           1.33 |          1.46
#          -0.47 |         -0.73
#          -0.80 |         -0.67
#          -1.42 |         -1.66
#          -0.18 |         -0.44
#          -1.49 |         -1.06
#           0.77 |          0.62
#           0.17 |         -0.07
#           0.61 |          0.65
#           0.15 |          0.20
#           1.50 |          1.44
#           0.80 |          0.31
#           0.61 |          0.45
#          -0.31 |         -0.02
#          -1.42 |         -1.75
#          -0.26 |         -0.75
#          -0.44 |         -0.02
#           0.45 |         -0.09
#          -2.34 |         -2.05
#           0.63 |          1.54
#           1.56 |          1.78
#          -0.08 |         -0.08
#          -0.35 |         -0.46
#           1.73 |          1.66
#           1.61 |          1.54
#           0.56 |          0.60
# ...

# %%
residual = actual- y_pred
print(residual)
# Out:
# [[-1.98206591e-01]
#  [ 1.04069693e+00]
#  [-1.57055587e+00]
#  [ 6.13314482e-01]
#  [ 5.53701042e-01]
#  [ 1.54667264e+00]
#  [ 3.24887166e-01]
#  [ 9.42701869e-01]
#  [-7.30939037e-01]
#  [-4.58975320e-02]
#  [-7.60714884e-01]
#  [-3.13728364e-01]
#  [-1.55706768e+00]
#  [-4.22803259e-01]
#  [-5.66965251e-01]
#  [-9.72426180e-02]
#  [ 1.63292192e+00]
#  [ 6.37530930e-01]
#  [-9.38129562e-02]
#  [-2.80715641e-02]
#  [ 1.93972703e+00]
#  [-1.65139734e+00]
#  [-1.89239278e+00]
#  [-3.46040679e-02]
#  [ 3.49854328e-01]
#  [-1.77342980e+00]
#  [-1.65020315e+00]
#  [-7.15595378e-01]
#  [-5.65869542e-01]
#  [-1.00344815e+00]
#  [ 1.31273265e+00]
#  [-1.60986737e+00]
#  [-7.78889517e-01]
#  [ 4.62226416e-01]
#  [-2.74981898e-01]
#  [ 7.69660271e-01]
#  [ 3.26900261e-03]
#  [ 5.36904066e-01]
#  [-4.01797568e-01]
#  [ 1.15418296e+00]
#  [-5.82983164e-01]
#  [ 1.73403785e+00]
#  [ 1.03918755e+00]
#  [-2.01080003e+00]
#  [-1.37540139e+00]
#  [ 6.29022750e-01]
#  [ 1.66365992e-01]
# ...

# %%
# Distribution plot for Residual (difference between actual and predicted values)
sns.distplot(residual, kde=True)
# Out:
# <Axes: ylabel='Density'>

# %%
y_pred = y_pred.squeeze()
y_test_scaled = y_test_scaled.squeeze()

# %%
sns.scatterplot(x=y_test_scaled, y=y_pred, color='blue', label='Actual Data points')
plt.plot([min(y_test_scaled), max(y_test_scaled)], [min(y_test_scaled), max(y_test_scaled)], color='red', label='Ideal Line')
plt.legend()
plt.show()

# %%
# Score It
from sklearn.metrics import mean_squared_error

print('Linear Regression Model')
# Results
print('--'*30)
# mean_squared_error(y_test_scaled, y_pred)
mse = mean_squared_error(y_test_scaled, y_pred)
rmse = np.sqrt(mse)

# Print evaluation metrics
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
# Out:
# Linear Regression Model
# ------------------------------------------------------------
# Mean Squared Error: 0.08162353645736904
# Root Mean Squared Error: 0.28569833121208293

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,accuracy_score

# %%
print('MAE', mean_absolute_error(y_test_scaled,y_pred))
# Out:
# MAE 0.231132744718741

# %%
print('MSE', mean_squared_error(y_test_scaled,y_pred))
# Out:
# MSE 0.08162353645736904

# %%
print('RMSE',np.sqrt( mean_absolute_error(y_test_scaled,y_pred)))
# Out:
# RMSE 0.4807626698473385

# %%
print('r2_Score', r2_score(y_test_scaled,y_pred))
# Out:
# r2_Score 0.921171916540202

# %%
# Check aaccuracy_score of decision tree regressor model on same data
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

rf_regressor = DecisionTreeRegressor()
rf_regressor.fit(x_train_scaled,y_train_scaled)

#Predicting the SalePrices using test set
y_pred_rf = rf_regressor.predict(x_test_scaled)

DTr = mean_squared_error(y_test_scaled,y_pred)
#Random Forest Regression Accuracy with test set
print('Decision Tree Regression : ',DTr)
# Out:
# Decision Tree Regression :  0.08162353645736904

# %%
# check aaccuracy_score gradian boosting regressor BGR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

rf_regressor = GradientBoostingRegressor()
rf_regressor.fit(x_train_scaled,y_train_scaled)

#Predicting the SalePrices using test set
y_pred_rf = rf_regressor.predict(x_test_scaled)

#Random Forest Regression Accuracy with test set
GBr = mean_squared_error(y_test_scaled,y_pred)
print('Gradient Boosting Regression : ',GBr)
# Out:
# Gradient Boosting Regression :  0.08162353645736904

# %%
# check aaccuracy_score on Random forest regressor model.
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

rf_regressor = RandomForestRegressor()
rf_regressor.fit(x_train_scaled,y_train_scaled)

#Predicting the SalePrices using test set
y_pred_rf = rf_regressor.predict(x_test_scaled)
RFr = mean_squared_error(y_test_scaled,y_pred)
#Random Forest Regression Accuracy with test set
print('Random Forest Regression : ',RFr)
# Out:
# Random Forest Regression :  0.08162353645736904

# %%
# Sample model scores 
model_scores = {
    "Linear Regression": 0.08162353645736904,
    "Descison Tree"    : 0.08162353645736904,
    "Random Forest"    :0.08162353645736904,
    "Gradient Boosting": 0.08162353645736904
}

# Sort the model scores in ascending order based on their values (lower values first)
sorted_scores = sorted(model_scores.items(), key=lambda x: x[1])

# Display the ranking of the models
print("Model Rankings (lower values are better):")
for rank, (model_name, score) in enumerate(sorted_scores, start=1):
    print(f"{rank}. {model_name}: {score}")
# Out:
# Model Rankings (lower values are better):
# 1. Linear Regression: 0.08162353645736904
# 2. Descison Tree: 0.08162353645736904
# 3. Random Forest: 0.08162353645736904
# 4. Gradient Boosting: 0.08162353645736904
